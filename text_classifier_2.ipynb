# %%
from os import listdir
from os.path import isfile, join
from sklearn.model_selection import train_test_split
import numpy as np
import unicodedata
import re
import string

mainPath = "D:\\Users\\matteus-paula\\Documents\\Projetos\\python\\desafio_mprj\\desafio-ia\\energia"

targetnames = list()
filenames = list()
target = list()
data = list()

def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    change_str = only_ascii.decode("utf-8")
    change_str = re.sub(r"[0-9]+","", change_str)
    change_str = re.sub(r"\r|\n|\t"," ", change_str)
    change_str = re.sub(r"\s\s+"," ", change_str)
    change_str = re.sub(r'[!"#$%&\'()*+,-./:;<=>?@\[\\\]^_`{|}~]+', "", change_str)
   
    return change_str.lower()


def load_data(targetnames, filenames, target, data, mainPath):

    for folder in listdir(mainPath):
        dir_folder = join(mainPath, folder)
        if not isfile(dir_folder):
            targetnames.append(folder)
            for file in listdir(dir_folder):
                file_path = join(dir_folder, file)
                if isfile(file_path):
                    target.append(targetnames.index(folder))
                    filenames.append(file_path)
                    with open(file_path, 'rb') as f:
                        compressed_content = f.read()
                    data.append(remove_accents(compressed_content.decode("utf-8")))

    return train_test_split(data, target, test_size=0.33, stratify=target, random_state=42)


X_train, X_test, y_train, y_test = load_data(targetnames, filenames, target, data, mainPath)
# Out:
# ['homologo para que surta seus efeitos legais o projeto de sentenca elaborado pelo juiz leigo na forma do artigo da lei no  apos o transito em julgado tratandose de sentenca de improcedencia ou de extincao do feito sem resolucao do merito dese baixa e arquivemse imediatamente tratandose de sentenca de procedencia aguardese por dias a manifestacao das partes e em seguida caso permanecam em silencio procedase a baixa e ao arquivamento adverte se as partes que antes da pratica de qualquer ato executivo uma vez escoado o prazo de dias previsto no art do cpc sem que tenha havido o cumprimento da obrigacao reconhecida na sentenca incidira automaticamente a multa de  dez por cento a que se refere o artigo e se procedera a intimacao da parte credora para que se manifeste no prazo de cinco dias sobre seu interesse em efetivar o protesto do titulo judicial na conformidade do art do ncpc e do ato executivo conjunto tjcgj n  publicado no dje em  pri',
#  'defiro jg a parte autora anotese tratase de pedido de antecipacao dos efeitos da tutela em que a parte autora requer ao juizo que determine a concessionaria re que promova a suspensao das cobrancas de parcelamento do debito oriundo do toi no e do comunicado de cobranca de irregularidade no  ate o julgamento finalitem de fl relata a parte autora que foi surpreendida com uma fatura com vencimento para o dia  com cobranca de parcelamento de debito em parcelas de r duzentos e setenta e nove reais e dez centavos dispoe o artigo do cpc que a tutela de urgencia sera concedida quando houver elementos que evidenciem a probabilidade do direito e o perigo de dano ou o risco ao resultado util do processo a probabilidade do direito encontrase demonstrada pelo acervo documental juntado a inicial e diante da adimplencia da autora quanto as faturas de energia eletrica o perigo de dano e se o autor nao pagar a conta de energia com a inclusao do valor que contesta em juizo podera ser penalizado com o corte de sua energia eletrica servico essencial a saude e aos afazeres do dia a dia vale ressaltar que a cobranca nao reconhecida pela autora referente a suposta irregularidade encontrada pela re no relogio medidor da demandante esta sendo discutida nessa dem
ao caso nao ocorra na data prevista eventual execucao deve vir com a prova pre constituida do descumprimento sob pena de indeferimento liminar ficando o credor advertido que caso obstacularize dificulte ou impeca o cumprimento da obrigacao fixada na sentenca podera ser reputado litigante de ma fe com a respectiva condenacao ao pagamento de custas quanto aos juros esclareco que em se tratando de responsabilidade extracontratual o termo inicial de sua fluencia sera a data do evento danoso em sendo a responsabilidade contratual a fluencia dos juros se dara a partir da citacao tal qual a correcao monetaria em qualquer caso considerando a entrada em vigor do cpc consigno que os prazos perante este juizado especial civel serao contados em dias corridos nos termos da nota tecnica  do forum nacional dos juizados especiais fonaje e entendimento resultante do aviso i nao se aplicando dessa forma o disposto no artigo do cpc  lei  publiquese intimemse registrada eletronicamente',
#  'homologo para que surta seus efeitos legais o projeto de sentenca elaborado pelo juiz leigo na forma do artigo da lei no  apos o transito em julgado tratandose de sentenca de improcedencia ou de extincao do feito sem resolucao do merito dese baixa e arquivemse imediatamente tratandose de sentenca de procedencia e havendo deposito voluntario pelo reu expecase mandado de pagamento apos aguardese por dias a manifestacao das partes e em seguida caso permanecam em silencio procedase a baixa e ao arquivamento pri',
#  'homologo o projeto de sentenca do juiz leigo supra na forma do art  da lei no  apos o transito em julgado certifiquese dese baixa na distribuicao e arquivemse os autos ficam as partes cientes de que os prazos no sistema do jec continuam sendo contados em dias corridos',
#  'diante da ausencia da parte autora na audiencia de conciliacao instrucao e julgamento embora devidamente intimada julgo extinto o processo sem apreciacao do merito com base no artigo i da lei  isento a parte autora do recolhimento de custas na forma do art  o da lei  apos as formalidades legais dese baixa e arquivemse pri',
#  'homologo por sentenca o acordo realizado pelas partes para que produza os seus efeitos legais face a sua regularidade formal e julgo extinto o processo na forma do artigo  iii b do cpc sem custas e honorarios dispensada a intimacao das partes nos termos do enunciado no  do aviso no  se for o caso de pagamento por deposito judicial apos sua efetivacao e a quitacao por parte do credor expecase mandado de pagamento apos dese baixa e arquivese',
#  'considerando os fatos narrados tendo em vista a essencialidade do servico prestado pela parte re com exclusividade entendo presentes os requisitos necessarios a concessao da medida pleiteada assim defiro a liminar pleiteada e determino que a parte re se abstenha de interromper o fornecimento de energia no imovel da autora codigo de instalacao indicado nas faturas de fls  sob pena de multa diaria no valor de r ise',
#  'homologo o projeto de sentenca proferido pelo juiz leigo para que produza seus juridicos e legais efeitos na forma do art da lei  ate deliberacao em contrario os prazos em sede de juizados especiais civeis continuarao a ser contados em dias corridos sendo inaplicavel o artigo do ncpc nos termos do aviso cojes no  publicado no doerj de  p  nas sentencas de procedencia com obrigacao de pagar fica a parte re ciente de que caso nao pague a quantia certa a que foi condenada em dias contados do transito em julgado da sentenca o valor da condenacao sera acrescido de multa de  por aplicacao do artigo  o do cpc sendo certo ainda que a comprovacao do deposito devera vir aos autos ate o o dia apos o termino do referido prazo fica desde ja cientificado o credor de que nao incidem em sede de juizados especiais civeis honorarios na fase de execucao eis que o rol do artigo da lei  e taxativo o que atende ainda a atual redacao do enunciado no do fonaje comprovado o deposito apos a quitacao integral das obrigacoes de pagar e fazer impostas na sentenca expecase mandado de pagamento em favor da parte autora apos dese baixa e arquivese caso negativo apos o decurso do prazo de trinta dias do transito em julgado nao havendo manifestacao dese baixa e arquivese cientes as partes na forma do artigo o o do ato normativo conjunto  modificado pelo ato executivo tj  que os autos processuais findos serao eliminados apos o prazo de noventa dias da data do arquivamento definitivo p i registrada eletronicamente ressalto que se a presente homologacao observou o prazo para leitura de sentenca o prazo recursal se iniciara da data designada para a leitura de sentenca e na hipotese do prazo para leitura de sentenca nao ter sido observado pelo juiz leigo o prazo recursal comecara a contar da regular intimacao das partes',
#  'defiro jg a inversao do onus a prova ser apreciada em data oportuna no entanto antes de proferir o despacho liminar positivo verifico que a autora em seu rol de pedidos faz pedido indenizatorio a ser arbitrado pelo juizo no entanto a luz do artigo  caput cc artigo do cpc nao ha mais a possibilidade de que o valor de indenizacao por danos morais seja arbitrado pelo juizo outrossim nao informou ao juizo o seu interesse ou nao na realizacao de audiencia de conciliacao prevista no artigo do cpc isto posto a parte autora para emendar a inicial apresentando emenda substitutiva como se fosse uma nova inicial fosse no prazo de dias sob pena de indeferimento da inicial da seguinte forma   quantificar claramente o valor de seu pedido indenizatorio a titulo de danos morais  e se for o caso corrigir o valor da causa  informar expressamente o seu interesse ou nao na realizacao de audiencia de conciliacao',
#  'dispensado o relatorio na forma do art  da lei  decido homologo o projeto de sentenca elaborado pelo juiz leigo que passa a valer como fundamentacao deste com fulcro na lei estadual no  e na resolucao no  do e orgao especial do tjrj e resolvese o merito com base no art  i do ncpc publiquese aguardese a data designada para a leitura de sentenca apos certificado o transito em julgado e comprovado o deposito no prazo devido expecase mandado de pagamento independente de nova conclusao nada mais havendo dese baixa e arquivese',
#  ' considerando que a probabilidade do direito e perigo do dano atraves dos elementos de prova expostos pelo autor em sua peca inicial nao se revelam presentes como determina o artigo do ncpc  considerando que a tutela de evidencia nao se encontra devidamente caracterizada como exige o artigo do ncpc  assim sendo indefiro a tutela de urgencia como requerida pelo autor   aguardese a instrucao processual quando a parte autora podera atraves de uma digressao probatoria mais robusta demonstrar a caracterizacao do direito e de sua urgencia',
#  'a parte autora pleiteia a concessao de antecipacao dos efeitos da tutela no direito brasileiro o instituto esta previsto no artigo do cpc que autoriza ao juiz conceder a parte um provimento quando lhe for evidenciado o direito e o perigo de dano ou o risco ao resultado util do processo cabe ressaltar que se trata de medida excepcional que so deve ser concedida quando preenchidos os requisitos previstos no art do cpc assim necessaria a verossimilhanca das alegacoes e a prova inequivoca do direito alegado bem como o fundado receio de dano irreparavel significa que deve a parte deve demonstrar liminarmente que a demora na tutela jurisdicional acarretara ao titular do direito um dano irreparavel ou de dificil reparacao bem como ao resultado do processo no que pertine as tutelas como se sabe o estatuto dos juizados especiais criou um sistema juridico proprio adequado para as causas civeis de menor complexidade que segue principios e regras proprios distintos daqueles estabelecidos pelo codigo de processo civil mas o sistema de tal codigo lhe e aplicavel de forma subsidiaria e desde que nao contrarie seus principios dentre eles o da efetividade
#  'hilda teixeira guimaraes propos a presente demanda em face da light servicos de eletricidade ltda pleiteando cancelamento de cobranca de valores cujo lancamento teve como motivo refaturamento unilateral realizado pela concessionaria por suposta violacao do relogio medidor reparacao moral e material decisao que defere a tutela pretendida a fl o reu ofertou contestacao as fls  aduzindo no merito a legalidade no lancamento da cobranca em razao de irregularidade constatada inexistencia de defeito no servico inocorrencia de danos impossibilidade de cancelamento e de repeticao de indebito a parte autora se manifestou em replica as fls  decisao saneadora a fl  nao foram produzidas novas provas vindo os autos conclusos para sentenca e o relatorio decido encerrada a instrucao probatoria e ja havendo decisao saneadora o feito encontrase maduro para provimento de merito no merito observo que assiste razao apenas em parte ao autor com efeito este juizo fixou entendimento no sentido de que concessionaria de energia eletrica constatando violacao do medidor retirando unilateralmente o aparelho e emitindo conta de refaturamento de energia esta cobrando por servico cuja medicao e ficticia o principio que rege a prestacao de servicos e de que o consumidor somente pagara pelo efetivamente prestado assim tal conta refaturamento constitui ilegalidade frente as regras que balizam a relacao prestadoraconsumidor para reparacao do dano advindo de furto de energia eletrica necessaria se faz a comprovacao da responsabilidade do consumidor pela violacao o que nao ocorreu in casu ainda que haja a constatacao de irregularidade e vedada a cobranca pelo consumo por estimativa devendo o consumidor arcar com o que efetivamente foi consumido dessa forma a conta de refaturamento decorrente do toi deve ser declarada cancelada e por ser considerada ilegal a cobranca cabivel a devolucao em dobro na forma do paragrafo unico do art do codigo de defesa do consumidor quanto aos danos morais nao vislumbro motivo a justificar seu acolhimento pois inexiste macula a honra objetiva ou subjetiva do autor ou qualquer outro fundamento a embasar o acolhimento do pedido assim ante a fundamentacao acima julgo procedente em parte o pedido e extingo o processo com julgamento do merito na forma do art  inciso i do cpc para confirmar a antecipacao de tutela deferida e cancelar a conta refaturamento ainda condeno a parte re a devolver os valores pagos a maior e devidamente comprovados nos autos na forma dobrada acrescidos de juros legais desde a citacao e corrigidos a partir do desembolso condeno a re ao pagamento de custas e honorarios que fixo em  do valor da condenacao ao transito baixa e arquivo publiquese registrese intimemse',
#  'homologo por sentenca para que produza os seus efeitos juridicos e legais o acordo estabelecido pelas partes nos presentes autos e declaro extinto feito em conformidade com o disposto no art  unico da lei  cc artigo  iii b do ncpc noticiado o cumprimento da transacao se for o caso expecase mandado de pagamento independente de conclusao observadas as cautelas de praxe sem despesas processuais eventual descumprimento do acordo ensejara pedido de execucao nestes mesmos autos ou em processo autonomo transitada em julgado dese baixa e arquivemse os autos anotese conforme requerido na ata de audiencia para fins de publicacao as partes ficam cientes de que os autos processuais findos dos juizados especiais civeis serao eliminados apos o prazo de dias da data do arquivamento definitivo ato executivo tj no  de  em caso de processo fisico pri',
#  'recebo a emenda de fls  pretende a autora em sede de tutela de urgencia a declaracao de inexistencia do debito imputado no toi no  bem como impedir a negativacao de seu nome nos cadastros restritivos de credito para concessao da medida de urgencia requerida impoese a caracterizacao dos requisitos previstos no art  do ncpc a probabilidade do direito e o perigo de dano ou o risco ao resultado util do processo a probabilidade que autoriza o emprego da tecnica antecipatoria para a tutela do direito invocado na inicial se traduz na probabilidade logica isto e o direito se afigura provavel a partir da analise das alegacoes e das provas que instruem a inicial o perigo de dano e o risco ao resultado util do processo requisitos dispostos pelo legislador de forma alternativa est
#  'homologo para que produza seus juridicos e legais efeitos a sentenca proferida pelo mm juiz leigo na forma do art da lei ',
#  'homologo para que produza seus juridicos e legais efeitos a sentenca proferida pelo mm juiz leigo na forma do art da lei ',
#  'parcial razao assiste a re nao cabe a execucao da multa tendo em vista que a emissao da fatura na qual constou o parcelamento foi expedida anteriormente a prolacao da sentenca no entanto e devida a devolucao do valor de multa e juros cobrados na fatura de fls em decorrencia do debito da fatura anterior que foi refaturada  assim intimese a parte re para que deposite o valor de r  no prazo de cinco dias sob pena de penhora',
#  'homologo para que produza seus juridicos e legais efeitos a sentenca proferida pelo mm juiz leigo na forma do art da lei ',
#  'indefiro o requerimento de tutela antecipada por nao vislumbrar na especie a incidencia dos requisitos previstos no art do cpc eventual prejuizo devera ser avaliado na epoca oportuna aguardese a audiencia ja designada',
#  'homologo o projeto de sentenca na forma do artigo da lei no  determino outrossim a expedicao de mandado de pagamento tao logo seja depositado o valor objeto da condenacao independente de nova conclusao certificado o transito em julgado dese baixa e arquivemse ficam as partes intimadas nos termos do ato executivo tj no  que os autos processuais serao eliminados decorridos dias da data do arquivamento definitivo independente de nova intimacao sem custas processuais e honorarios advocaticios na forma do artigo da lei no  pri',
#  'vistos etc dispensado o relatorio na forma do artigo da lei  decido homologo por sentenca o acordo com fulcro na lei estadual no  e na resolucao no  do e orgao especial do tjrj julgo extinto o processo com exame do merito com base no art  iii b do cpc comprovado o deposito judicial se for o caso existindo obrigacao de pagar intimese a parte autora para dizer no prazo de dias se da quitacao quanto a todas as obrigacoes constantes do acordo valendo o silencio como concordancia o que sera considerado renuncia a eventual diferenca de valores a titulo de credito considerandose inclusive o silencio como afirmacao quanto ao cumprimento de eventual obrigacao de fazer acordada com o reu nesse passo sendo dada a quitacao tacita ou expressa expecase mandado de pagamento em favor da parte credora com as devidas cautelas independente de nova conclusao apos certificado o transito nada mais havendo dese baixa e arquivemse pri',
#  'homologo para que produza seus juridicos e legais efeitos o acordo efetivado pelas partes litigantes em audiencia e em consequencia julgo extinto o feito com exame do merito nos termos do artigo  iii b do cpc sem custas p i com a comprovacao do deposito o que devera vir aos autos ate o o dia apos o termino do prazo para o respectivo deposito expecase mandado de pagamento se o caso em nome do autor eou seu patrono caso possua poderes apos dese baixa e arquivemse cientes as partes na forma do artigo o o do ato normativo conjunto  publicado no doerj em  que os autos processuais findos serao eliminados apos o prazo de cento e oitenta dias da data do arquivamento definitivo',
# ...
#  'recebo os embargos e dou provimento para constar na sentenca a condenacao da re ao pagamento do valor de r  a titulo de condencao por danos materiais acrescido de juros de  aos mes e correcao monetaria a partir do desembolso a restituicao devera ocorrer na forma simples eis que nao verificada a mafe da re mantendose no mais a sentenca tal como foi lancada',
as com valores acima do habitualmente apurado em funcao da insercao do valor do referido parcelamento que e objeto de impugnacao assim defiro parcilamente a tutela antecipada para determinar que a empresa re abstenhase de efetuar a suspensao no fornecimento de energia eletrica na residencia da parte autora sob pena de multa diaria de r  limitada inicialmente a r  considerando tratarse de prestacao de trato sucessivo intimese a empresa re para emitir as faturas vincendas sem incidencia de cobranca de qualquer parcela atinente ao valor aqui contestado a partir da proxima fatura a vencer depois de sua intimacao observado o prazo minimo de dias sob pena de multa equivalente ao quintuplo do que for cobrado indevidamente ressalto que a tutela ora concedida se restringe aos fatos e valores impugnados neste processo devendo a parte autora promover o pagamento tempestivo das faturas nao impugnadas ate a solucao final da lide sob pena de revogacao da presente decisao designo audiencia de conciliacao para o dia  as h na forma do artigo do ncpc citemse os reus pessoalmente por oja ante a tutela antecipada concedida para que comparecam a audiencia de conciliacao designada se entender pela possibilidade de composicao do litigio mediante apresentacao de proposta e acompanhados de advogado cientificandoos de que sua ausencia injustificada e sem proposta sera considerada ato atentatorio a dignidade de justica e ensejara imposicao de multa art  o ncpc ressalto que a parte re podera se valer do preceituado no art  o do cpc se entender que nao ha possibilidade de composicao do litigio facase constar do mandado a advertencia de que o prazo para oferecimento da contestacao sera de quinze dias contados da data da audiencia de conciliacao art  i ncpc ou na hipotese de nao optar por sua realizacao no prazo preconizado no art  ii do ncpc fica a parte autora intimada para comparecimento na pessoa de seu advogado art  o ncpc ciente de que sua ausencia injustificada a audiencia sera considerada ato atentatorio a dignidade de justica e ensejara a imposicao de multa art  o ncpc publiquese',
#  'nao estao presentes os requisitos do art  do ncpc necessitando o juizo de mais elementos ate mesmo para o juizo de probabilidade isto posto indefiro a antecipacao dos efeitos da tutela pleiteada',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from stop_words import get_stop_words

stop_words_pt = get_stop_words('portuguese')

count_vect = CountVectorizer(stop_words=stop_words_pt)

X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape
# Out:
# (53384, 22017)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)

X_train_tf = tf_transformer.transform(X_train_counts)

X_train_tf.shape
# Out:
# (53384, 22017)

# %%
tfidf_transformer = TfidfTransformer()

X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

X_train_tfidf.shape
# Out:
# (53384, 22017)

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
docs_new = ['perigo de dano eletronico ficou evidenciado', 'sob pena de multa']

X_new_counts = count_vect.transform(docs_new)

X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

for doc, category in zip(docs_new, predicted):
    print('%r => %s' % (doc, targetnames[category]))
# Out:
# 'perigo de dano eletronico ficou evidenciado' => DanosEletrodomesticos
# 'sob pena de multa' => InterrupcaoInstabilidadeFornecimento

# %%
from sklearn.pipeline import Pipeline

text_clf = Pipeline([('vect', CountVectorizer(stop_words=stop_words_pt)),
                     ('tfidf', TfidfTransformer()), 
                     ('clf', MultinomialNB()),])

text_clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words=['a', 'ao',...inear_tf=False, use_idf=True)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
docs_test = X_test
predicted = text_clf.predict(docs_test)
np.mean(predicted == y_test)
# Out:
# 0.8716437210009889

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
    KNeighborsClassifier(n_neighbors=8),
    SGDClassifier(loss='hinge', penalty='l2',
                           alpha=1e-3, random_state=42,
                           max_iter=5, tol=None),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, X_train_tfidf, y_train, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
cv_df.groupby('model_name').accuracy.mean()
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# model_name
# KNeighborsClassifier      0.940113
# LinearSVC                 0.980237
# LogisticRegression        0.963435
# MultinomialNB             0.873575
# RandomForestClassifier    0.750710
# SGDClassifier             0.930822
# Name: accuracy, dtype: float64

# %%
text_clf = Pipeline([
     ('vect', CountVectorizer(stop_words=stop_words_pt)),
     ('tfidf', TfidfTransformer()),
     ('clf', OneVsRestClassifier(LinearSVC(class_weight='balanced'))),
    
])

text_clf.fit(X_train, y_train)
predicted = text_clf.predict(docs_test)
np.mean(predicted == y_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.9814786643340686

# %%
from sklearn import metrics

s = set(y_test)
target_names_test = [targetnames[i] for i in s]


print(metrics.classification_report(y_test, predicted,
target_names=target_names_test))
# Out:
#                                            precision    recall  f1-score   support
#
#               CobrancaServicoNaoFornecido       0.93      0.76      0.84        54
#                         CobrancaSobAmeaca       0.98      0.99      0.98      3799
#                            CobrancaTarifa       0.42      0.86      0.56        44
#                     DanosEletrodomesticos       0.96      0.98      0.97      3886
# DificuldadeContratacaoRecusaInjustificada       0.88      0.92      0.90       304
#                   DificuldadeRenegociacao       0.62      0.42      0.50       101
#      InterrupcaoInstabilidadeFornecimento       0.99      0.99      0.99     18085
#                       NegativacaoIndevida       1.00      0.57      0.73        21
#
#                                 micro avg       0.98      0.98      0.98     26294
#                                 macro avg       0.85      0.81      0.81     26294
#                              weighted avg       0.98      0.98      0.98     26294

# %%
metrics.confusion_matrix(y_test, predicted)
# Out:
# array([[ 37,   1,   0,   0,   4,   5,   9,   0],
#        [  0, 331,   0,   3,   1,   1,   2,   0],
#        [  0,   2,  49,   1,   1,   1,   2,   0],
#        [  0,   4,   0, 308,   7,   0,  11,   0],
#        [  0,   6,   0,  10, 280,   0,   1,   0],
#        [  1,  39,   1,   4,   6,  34,   4,   1],
#        [  0,  25,   0,  15,   6,   3, 282,   0],
#        [  1,   4,   2,   0,   0,   2,   0,   8]], dtype=int64)
